# %%
# !pip install numpy
# !pip install sympy
# !pip install scipy
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\cdlc_johnh\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: sympy in c:\users\cdlc_johnh\anaconda3\lib\site-packages (1.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from sympy) (1.3.0)
# Requirement already satisfied: scipy in c:\users\cdlc_johnh\anaconda3\lib\site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from scipy) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\cdlc_johnh\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\cdlc_johnh\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\cdlc_johnh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import math
import numpy as np
import sympy as sp
import scipy
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # CAU Physical Chemistry 3

# %% [markdown]
# ## 1. Dirac Delta function

# %% [markdown]
# ####  Dirac Delta function은 아주 결정적인 함수입니다. 그 어떠한 오차도 허용하지 않지요.
# ####  수업에서 여러가지 정의로 소개가 되었는데, 이번 시간에는 Fourier Transform으로 정의된 Dirac Delta 함수를 살펴 볼게요 🫡
# ####  먼저 Dirac Delta 함수의 모양은 다음과 같습니다

# %%
import numpy as np
import matplotlib.pyplot as plt

# x 범위 설정
x = np.linspace(-1, 1, 1000)
epsilon = 0.0005  # 작은 값
delta = (1 / (np.pi * epsilon)) / (1 + (x / epsilon)**2)  # 로런츠 분포 근사

plt.figure(figsize=(6, 4))
plt.plot(x, delta, label="Lorentzian Approximation", color="green")
plt.xlabel("x")
plt.ylabel("δ(x)")
plt.title("Lorentzian Approximation of Dirac Delta")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ####  함수 정의상
# ####  $$ x=0 $$  에서 무한대의 값을 가져야 합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

# X 범위 설정 (0 ~ 5)
x_vals = np.linspace(0, 5, 1000)
x_p = 0  # x' 값 (임의로 0으로 설정)

# 여러 k 값에 대해 적분 그래프 그리기
k_values = [0, 1, 3, 5, 7, 9, 10]  # 여러 주파수 k
colors = ['#f71000', '#f73325', '#fa4d41', '#fc685d','#ff8178','#fc9992','#fabdb9']

plt.figure(figsize=(8, 5))

for k, color in zip(k_values, colors):
    y_vals = np.cos(k * (x_vals - x_p))  # 각 k에 대한 cos 함수
    plt.plot(x_vals, y_vals, label=f'k = {k}', color=color)

# 그래프 설정
plt.xlabel("x")
plt.ylabel("Integral Value")
plt.title("Overlapping Cosine Integrals for Different k")
plt.legend()
plt.grid()
plt.show()

# %%
x_vals = np.linspace(0, 5, 1000)
x_prime = 0  # x' 값 (임의로 0으로 설정)

# 여러 k 값에 대해 적분 그래프 그리기
k_values = np.arange(0,11)  # 여러 주파수 k

plt.figure(figsize=(8, 5))

# y_vals는 k값들을 반복하며 각 cos(k * (x_vals - x_prime))을 합산합니다.
y_vals = np.zeros_like(x_vals)
for k in k_values:
    y_vals += np.cos(k * (x_vals - x_prime))

# 그래프 그리기
plt.plot(x_vals, y_vals, label='Total Sumed Cosine', color='#f71000')

# 그래프 설정
plt.xlabel("x")
plt.ylabel("Integral Value")
plt.title("Sumed Cosine Integrals for Different k")
plt.legend()
plt.grid()
plt.show()

# %%
x_vals = np.linspace(0, 5, 1000)
x_prime = 0  # x' 값 (임의로 0으로 설정)

# 여러 k 값에 대해 적분 그래프 그리기
k_values = np.arange(0,101)  # 여러 주파수 k

plt.figure(figsize=(8, 5))

# y_vals는 k값들을 반복하며 각 cos(k * (x_vals - x_prime))을 합산합니다.
y_vals = np.zeros_like(x_vals)
for k in k_values:
    y_vals += np.cos(k * (x_vals - x_prime))

# 그래프 그리기
plt.plot(x_vals, y_vals, label='Total Sumed Cosine', color='#f71000')

# 그래프 설정
plt.xlabel("x")
plt.ylabel("Integral Value")
plt.title("Sumed Cosine Integrals for Different k")
plt.legend()
plt.grid()
plt.show()

# %%
a = [1:1000]
print(a)
# Out:
#   Cell In[78], line 1
#     a = [1:1000]
#           ^
# SyntaxError: invalid syntax
